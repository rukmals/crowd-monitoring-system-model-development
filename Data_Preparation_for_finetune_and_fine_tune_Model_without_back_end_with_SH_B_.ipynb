# %% [markdown]
# <a href="https://colab.research.google.com/github/rukmals/crowd-monitoring-system-model-development/blob/main/Data_Preparation_for_finetune_and_fine_tune_Model_without_back_end_with_SH_B_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import os
import numpy as np
import h5py
import glob
import json

import sys
import warnings
# import from library
import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import datasets, transforms
import numpy as np
import json
import cv2
import time
from torchvision import models

# %%
import os
import random
import torch
import numpy as np
from torch.utils.data import Dataset
from PIL import Image

def load_data(img_path,train = True):
    gt_path = img_path.replace('.jpg','.h5').replace('images','ground-truth-h5')
    img = Image.open(img_path).convert('RGB')
    gt_file = h5py.File(gt_path, 'r')
    target = np.asarray(gt_file['density'])
    target = target.astype(np.float32, copy=False)
    target = Image.fromarray(target)
    return img,target

class ListDataset(Dataset):
    def __init__(self, root, shape=None, shuffle=True, main_transform = None , img_transform=None, gt_transform = None, train=False, batch_size=1, num_workers=4):
        """
        if you have different image size, then batch_size must be 1
        :param root:
        :param shape:
        :param shuffle:
        :param transform:
        :param train:
        :param seen:
        :param batch_size:
        :param num_workers:
        """
        #if train:
            #root = root *4
        if shuffle:
            random.shuffle(root)
        
        self.nSamples = len(root)
        self.lines = root
        self.main_transform = main_transform
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.train = train
        self.shape = shape
        self.batch_size = batch_size
        self.num_workers = num_workers
        
    def __len__(self):
        return self.nSamples

    def __getitem__(self, index):
        assert index <= len(self), 'index range error' 
        
        img_path = self.lines[index]
        
        img,target = load_data(img_path,self.train)

        if self.main_transform is not None:
            img, target = self.main_transform(img, target)
        if self.img_transform is not None:
            img = self.img_transform(img)
        if self.gt_transform is not None:
            target = self.gt_transform(target)   
        return img,target

# %%
img , target = load_data("/content/drive/MyDrive/Model_Test_Data/PartB/test_data/images/IMG_1.jpg")

# %%
#img

# %%
import numbers
import random
import numpy as np
from PIL import Image, ImageOps, ImageFilter
import torch

class LabelNormalize(object):
    def __init__(self, para):
        self.para = para

    def __call__(self, tensor):
        # tensor = 1./(tensor+self.para).log()
        tensor = torch.from_numpy(np.array(tensor))
        tensor = tensor*self.para
        return tensor

# ===============================img tranforms============================

class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, mask, bbx=None):
        if bbx is None:
            for t in self.transforms:
                img, mask = t(img, mask)
            return img, mask
        for t in self.transforms:
            img, mask, bbx = t(img, mask, bbx)
        return img, mask, bbx

class RandomHorizontallyFlip(object):
    def __call__(self, img, mask, bbx=None):
        if random.random() < 0.5:# 随机生成0-1之间的浮点数 ，每次执行生成的不一样
            if bbx is None:
                return img.transpose(Image.FLIP_LEFT_RIGHT), mask.transpose(Image.FLIP_LEFT_RIGHT)
            w, h = img.size
            xmin = w - bbx[:,3]
            xmax = w - bbx[:,1]
            bbx[:,1] = xmin
            bbx[:,3] = xmax
            return img.transpose(Image.FLIP_LEFT_RIGHT), mask.transpose(Image.FLIP_LEFT_RIGHT), bbx
        if bbx is None:
            return img, mask
        return img, mask, bbx

class RandomCrop(object):
    def __init__(self, size, padding=0):
        if isinstance(size, numbers.Number):
            self.size = (int(size), int(size))
        else:
            self.size = size
        self.padding = padding

    def __call__(self, img, mask):
        # if self.padding > 0:
        #     img = ImageOps.expand(img, border=self.padding, fill=0)
        #     mask = ImageOps.expand(mask, border=self.padding, fill=0)
        #
        # assert img.size == mask.size
        w, h = img.size
        th, tw  = self.size
        if w == tw and h == th:
            return img, mask
        if w < tw or h < th:
            return img.resize((tw, th), Image.BILINEAR), mask.resize((tw, th), Image.NEAREST)

        x1 = random.randint(0, w - tw)
        y1 = random.randint(0, h - th)
        return img.crop((x1, y1, x1 + tw, y1 + th)), mask.crop((x1, y1, x1 + tw, y1 + th))

# %%
img_train_list = os.listdir("/content/drive/MyDrive/Model_Test_Data/PartB/train_data/images")
img_list = []
for img in img_train_list:
  if '.jpg' in img:
    img_list.append(img)

sh_train_list = []
for img_ in img_list:
  img_ = "/content/drive/MyDrive/Model_Test_Data/PartB/train_data/images/"+img_
  sh_train_list.append(img_)

# %%
len(sh_train_list)
# Out:
# 400

# %%
tar_main_transform = Compose([
        RandomCrop(((576,768))),
        RandomHorizontallyFlip(),
        # Rand_Augment()
    ])

tar_shot_loader = torch.utils.data.DataLoader(ListDataset(sh_train_list,shuffle=True,
                                                                main_transform = tar_main_transform,
                                                                img_transform=transforms.Compose([
                                                                transforms.ToTensor(), 
                                                                transforms.Normalize(mean=[0.302234709263, 0.291243076324, 0.269087553024],
                                                                                 std=[0.227743327618, 0.211051672697, 0.184846073389]),
                                                                ]),
                                                                gt_transform = transforms.Compose([
                                                                                LabelNormalize(100)
                                                                ]),
                                                                train=True,
                                                                batch_size=2,
                                                                num_workers=2),batch_size=2)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

class Conv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, \
                stride=1, NL='relu', same_padding=False, bn=False, dilation=1):
        super(Conv2d, self).__init__()
        padding = int((kernel_size - 1) // 2) if same_padding else 0
        self.conv = []
        if dilation==1:
            self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=padding, dilation=dilation)
        else:
            self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=dilation, dilation=dilation)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001, momentum=0, affine=True) if bn else nn.Identity()
        if NL == 'relu' :
            self.relu = nn.ReLU(inplace=True)
        elif NL == 'prelu':
            self.relu = nn.PReLU()
        else:
            self.relu = None

    def forward(self, x):
      x = self.conv(x)
      if self.bn is not None:
          x = self.bn(x)
      if self.relu is not None:
          x = self.relu(x)   
      return x
  
# the module definition for the multi-branch in the density head
class MultiBranchModule(nn.Module):
    def __init__(self, in_channels, sync=False):
        super(MultiBranchModule, self).__init__()
        self.branch_column1_1 = BasicConv2d(in_channels, in_channels//2, kernel_size=1, sync=sync)
        self.branch_column1_2 = BasicConv2d(in_channels//2, in_channels, kernel_size=1, sync=sync)

        self.branch_column2_1 = BasicConv2d(in_channels, in_channels//2, kernel_size=1, sync=sync)
        self.branch_column2_2 = BasicConv2d(in_channels // 2, in_channels, kernel_size=(3, 3), padding=(1, 1), sync=sync)

        self.branch_column3_1 = BasicConv2d(in_channels, in_channels//2, kernel_size=1, sync=sync)
        self.branch_column3_2 = BasicConv2d(in_channels // 2, in_channels, kernel_size=5, padding=2, sync=sync)

    def forward(self, x):
        branch_1 = self.branch_column1_1(x)
        branch_1 = self.branch_column1_2(branch_1)

        branch_2 = self.branch_column2_1(x)
        branch_2 = self.branch_column2_2(branch_2)

        branch_3 = self.branch_column3_1(x)
        branch_3 = self.branch_column3_2(branch_3)

        outputs = [branch_1, branch_2, branch_3, x]
        return torch.cat(outputs, 1)

# the module definition for the basic conv module
class BasicConv2d(nn.Module):

    def __init__(self, in_channels, out_channels, sync=False, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        if sync:
            # for sync bn
            print('use sync inception')
            self.bn = nn.SyncBatchNorm(out_channels, eps=0.001)
        else:
            self.bn = nn.BatchNorm2d(out_channels, eps=0.001)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return F.relu(x, inplace=True)


class TestNet(nn.Module):
    def __init__(self, pretrained=True):
        super(TestNet, self).__init__()
        
        vgg = models.vgg16_bn(pretrained=pretrained)
        
        self.backend_feat  = [256,128,64]


        # Front End Development VGG - 16 
        features = list(vgg.features.children())
        # get each stage of the VGG - 16
        self.features1 = nn.Sequential(*features[0:6])
        self.features2 = nn.Sequential(*features[6:13])
        self.features3 = nn.Sequential(*features[13:23])
        self.features4 = nn.Sequential(*features[23:33])
        self.features5 = nn.Sequential(*features[33:43])

        # Front End Development P1 to P5 
        self.p5 = nn.Sequential(
            Conv2d(512, 1024, 3, same_padding=True, NL='relu'),
            Conv2d(1024, 512, 3, same_padding=True, NL='relu'),
        )

        self.p4 = nn.Sequential(
            Conv2d(1024, 512, 3, same_padding=True, NL='relu'),
            Conv2d(512, 256, 3, same_padding=True, NL='relu'),
        )

        self.p3 = nn.Sequential(
            Conv2d(512 , 256, 3, same_padding=True, NL='relu'),
            Conv2d(256, 128, 3, same_padding=True, NL='relu'),
        )

        self.p2 = nn.Sequential(
            Conv2d(256, 128, 3, same_padding=True, NL='relu'),
            Conv2d(128, 64, 3, same_padding=True, NL='relu'),
        )

        self.p1 = nn.Sequential(
            Conv2d(128, 64, 3, same_padding=True, NL='relu'),
            Conv2d(64, 64, 3, same_padding=True, NL='relu'),
        ) 

        # Multi-Branch moules
        self.multi_branch5 = nn.Sequential(
            MultiBranchModule(512),
            Conv2d(2048, 1, 1, same_padding=True)
        )

        self.multi_branch4 = nn.Sequential(
            MultiBranchModule(256),
            Conv2d(1024, 1, 1, same_padding=True)
        )

        self.multi_branch3 = nn.Sequential(
            MultiBranchModule(128),
            Conv2d(512, 1, 1, same_padding=True)
        )

        self.multi_branch2 = nn.Sequential(
            MultiBranchModule(64),
            Conv2d(256, 1, 1, same_padding=True)
        )

        self.multi_branch1 = nn.Sequential(
            MultiBranchModule(64),
            Conv2d(256, 1, 1, same_padding=True)
        )

        self.backend = make_layers(self.backend_feat,in_channels = 5,dilation = True)

        self.output_layer = nn.Conv2d(5, 1, kernel_size=1)

    
    
    def forward(self, x):
        size = x.size()
        x1 = self.features1(x)
        x2 = self.features2(x1)
        x3 = self.features3(x2)
        x4 = self.features4(x3)
        x5 = self.features5(x4)

        # Front End Development P1 to P5 
        x = self.p5(x5)
        x5_out = x
        x = F.upsample_bilinear(x, size=x4.size()[2:])

        x = torch.cat([x4, x], 1)
        x = self.p4(x)
        x4_out = x
        x = F.upsample_bilinear(x, size=x3.size()[2:])

        x = torch.cat([x3, x], 1)
        x = self.p3(x)
        x3_out = x
        x = F.upsample_bilinear(x, size=x2.size()[2:])

        x = torch.cat([x2, x], 1)
        x = self.p2(x)
        x2_out = x
        x = F.upsample_bilinear(x, size=x1.size()[2:])

        x = torch.cat([x1, x], 1)
        x = self.p1(x)
        x1_out = x


        # multi-branch predictions
        x5_density = self.multi_branch5(x5_out)
        x4_density = self.multi_branch4(x4_out)
        x3_density = self.multi_branch3(x3_out)
        x2_density = self.multi_branch2(x2_out)
        x1_density = self.multi_branch1(x1_out)

        # upsample the multi-branch predictions to be the same with the input size
        x5_density = F.upsample_nearest(x5_density, size=x1.size()[2:])
        x4_density = F.upsample_nearest(x4_density, size=x1.size()[2:])
        x3_density = F.upsample_nearest(x3_density, size=x1.size()[2:])
        x2_density = F.upsample_nearest(x2_density, size=x1.size()[2:])
        x1_density = F.upsample_nearest(x1_density, size=x1.size()[2:])


        density_map = torch.cat([x5_density, x4_density, x3_density, x2_density, x1_density], 1)


        #x_out = self.backend(density_map)
        density_map_out = self.output_layer(density_map)
        return density_map_out
        #return density_map
                
                
def make_layers(cfg, in_channels = 3,batch_norm=False,dilation = False):
    layers = []
    dilation_rates = [2,3,5]
    #for v in cfg:
    for v in range(len(cfg)):
        if cfg[v] == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, cfg[v], kernel_size=3, padding=dilation_rates[v],dilation = dilation_rates[v])
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(cfg[v]), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = cfg[v]
    return nn.Sequential(*layers)

# %%
model_path = '/content/drive/MyDrive/GCC_CSV_DataSet/model/TestNetGCC_whole_data_withoutbackend.pth'

tar_model = TestNet().cuda()
# load the trained model
tar_model.load_state_dict(torch.load(model_path))
#checkpoint = torch.load(PATH)
#model.load_state_dict(checkpoint['model_state_dict'])
print('successfully load model from', model_path)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# successfully load model from /content/drive/MyDrive/GCC_CSV_DataSet/model/TestNetGCC_whole_data_withoutbackend.pth

# %%
lr = 1e-5
tar_optimizer =  torch.optim.Adam(tar_model.parameters(), lr = lr, weight_decay=1e-4)

# %%
for epoch in range(1,14):
  for i, (shot_img, shot_label) in enumerate(tar_shot_loader, 1):
    if i <= 50:
      shot_img = shot_img.cuda()
      shot_label = shot_label.cuda()
      shot_pred = tar_model(shot_img)

      loss = F.mse_loss(shot_pred.squeeze(), shot_label.squeeze())
      tar_optimizer.zero_grad()
      loss.backward()
      tar_optimizer.step()
    else:
      break
MODEL_SAVE_PATH = '/content/drive/MyDrive/GCC_CSV_DataSet/model/TestNetGCC_whole_data_withoutbackend_finetuned_SH_B.pth'
torch.save(tar_model.state_dict(), MODEL_SAVE_PATH)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3825: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3770: UserWarning: nn.functional.upsample_nearest is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_nearest is deprecated. Use nn.functional.interpolate instead.")

# %% [markdown]
# # Testing

# %%
img_test_list = os.listdir("/content/drive/MyDrive/Model_Test_Data/PartB/test_data/images")
img_test_name = []
for img in img_test_list:
  if '.jpg' in img:
    img_test_name.append(img)
img_test_name.remove("IMG_239 (1).jpg")
sh_test_list = []
for img_ in img_test_name:
  img_ = "/content/drive/MyDrive/Model_Test_Data/PartB/test_data/images/"+img_
  sh_test_list.append(img_)

# %%
len(sh_test_list)
# Out:
# 316

# %%
model_path = '/content/drive/MyDrive/GCC_CSV_DataSet/model/TestNetGCC_whole_data_withoutbackend_finetuned_SH_B.pth'

model = TestNet().cuda()
# load the trained model
model.load_state_dict(torch.load(model_path))
print('successfully load model from', model_path)
# Out:
# successfully load model from /content/drive/MyDrive/GCC_CSV_DataSet/model/TestNetGCC_whole_data_withoutbackend_finetuned_SH_B.pth

# %%
pred_transform=transforms.Compose([transforms.ToTensor(), 
                                  transforms.Resize(480), 
                                  transforms.Normalize(mean=[0.302234709263, 0.291243076324, 0.269087553024],
                                  std=[0.227743327618, 0.211051672697, 0.184846073389]),])

# %%
mae = 0
for im_path in sh_test_list:
  image = Image.open(im_path).convert('RGB')
  #print(image.shape)
  output = model(pred_transform(image)[None].cuda())
  gt_path = im_path.replace('.jpg','.h5').replace('images','ground-truth-h5')
  gt_file = h5py.File(gt_path, 'r')
  target = np.asarray(gt_file['density'])
  print("ground trueth count", np.sum(target))
  output = output.cpu()
  output = output.detach().numpy()
  print("Model Predicted Count",np.sum(output)/100)
  
  mae += abs(np.sum(target) -np.sum(output)/100)

mae = mae / len(sh_test_list)
print(' * TESTING MAE {mae:.3f} '.format(mae=mae))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3825: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3770: UserWarning: nn.functional.upsample_nearest is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_nearest is deprecated. Use nn.functional.interpolate instead.")
# ground trueth count 172.99678
# Model Predicted Count 126.314853515625
# ground trueth count 21.089602
# Model Predicted Count 16.163916015625
# ground trueth count 33.12424
# Model Predicted Count 33.51378173828125
# ground trueth count 64.97026
# Model Predicted Count 66.6046630859375
# ground trueth count 156.47859
# Model Predicted Count 84.62841796875
# ground trueth count 53.26684
# Model Predicted Count 77.1017919921875
# ground trueth count 41.2734
# Model Predicted Count 20.9736083984375
# ground trueth count 470.27805
# Model Predicted Count 282.834609375
# ground trueth count 160.92084
# Model Predicted Count 114.2443359375
# ground trueth count 216.71764
# Model Predicted Count 114.889404296875
# ground trueth count 103.04705
# Model Predicted Count 70.3467724609375
# ground trueth count 156.65094
# Model Predicted Count 90.78748046875
# ground trueth count 132.69264
# Model Predicted Count 89.99013671875
# ground trueth count 17.747625
# Model Predicted Count 57.56646484375
# ground trueth count 302.12555
# Model Predicted Count 105.23005859375
# ground trueth count 43.918083
# Model Predicted Count 33.9185546875
# ground trueth count 100.53064
# Model Predicted Count 57.408388671875
# ground trueth count 126.09301
# Model Predicted Count 85.2056640625
# ground trueth count 178.91074
# Model Predicted Count 135.778828125
# ground trueth count 201.80551
# Model Predicted Count 143.76677734375
# ground trueth count 37.403755
# Model Predicted Count 62.20271484375
# ground trueth count 144.58171
# Model Predicted Count 66.3962060546875
# ground trueth count 141.70612
# Model Predicted Count 86.15044921875
# ground trueth count 170.03862
# Model Predicted Count 45.8714208984375
# ground trueth count 502.9125
# Model Predicted Count 246.33017578125
# ground trueth count 66.5012
# Model Predicted Count 55.7127294921875
# ground trueth count 47.57452
# Model Predicted Count 23.66599365234375
# ground trueth count 52.657825
# Model Predicted Count 49.5999609375
# ground trueth count 62.62307
# Model Predicted Count 38.26192626953125
# ground trueth count 163.29704
# Model Predicted Count 79.458525390625
# ground trueth count 53.06145
# Model Predicted Count 20.50061767578125
# ground trueth count 70.31636
# Model Predicted Count 74.1629052734375
# ground trueth count 29.417793
# Model Predicted Count 18.897044677734375
# ground trueth count 44.93991
# Model Predicted Count 19.346343994140625
# ground trueth count 142.61313
# Model Predicted Count 98.45794921875
# ground trueth count 75.53449
# Model Predicted Count 39.0779638671875
# ground trueth count 156.5211
# Model Predicted Count 76.4157666015625
# ground trueth count 132.56813
# Model Predicted Count 94.400703125
# ground trueth count 112.99884
# Model Predicted Count 76.63869140625
# ground trueth count 115.471855
# Model Predicted Count 86.680048828125
# ground trueth count 66.361496
# Model Predicted Count 76.223779296875
# ground trueth count 114.73415
# Model Predicted Count 88.59587890625
# ground trueth count 27.828218
# Model Predicted Count 17.827183837890626
# ground trueth count 128.66205
# Model Predicted Count 84.09947265625
# ground trueth count 196.06589
# Model Predicted Count 116.64314453125
# ground trueth count 141.4771
# Model Predicted Count 53.1898779296875
# ground trueth count 32.121964
# Model Predicted Count 55.9974853515625
# ground trueth count 68.52043
# Model Predicted Count 45.1798583984375
# ground trueth count 20.735344
# Model Predicted Count 41.1534130859375
# ground trueth count 246.08884
# Model Predicted Count 149.458037109375
# ground trueth count 55.369694
# Model Predicted Count 62.4797509765625
# ground trueth count 239.15462
# Model Predicted Count 144.9882421875
# ground trueth count 65.622215
# Model Predicted Count 55.597109375
# ground trueth count 56.482704
# Model Predicted Count 54.413359375
# ground trueth count 245.76643
# Model Predicted Count 172.61435546875
# ground trueth count 44.817482
# Model Predicted Count 47.3877001953125
# ground trueth count 51.538033
# Model Predicted Count 26.50938720703125
# ground trueth count 116.412895
# Model Predicted Count 73.74072265625
# ground trueth count 144.44516
# Model Predicted Count 91.267626953125
# ground trueth count 166.20653
# Model Predicted Count 70.3809033203125
# ground trueth count 291.06662
# Model Predicted Count 152.330634765625
# ground trueth count 493.45804
# Model Predicted Count 272.3078125
# ground trueth count 459.2259
# Model Predicted Count 242.57056640625
# ground trueth count 84.976524
# Model Predicted Count 60.2454296875
# ground trueth count 42.599266
# Model Predicted Count 41.881904296875
# ground trueth count 38.490593
# Model Predicted Count 45.5650341796875
# ground trueth count 257.5392
# Model Predicted Count 132.625615234375
# ground trueth count 87.937874
# Model Predicted Count 62.295615234375
# ground trueth count 114.01151
# Model Predicted Count 97.966826171875
# ground trueth count 43.79727
# Model Predicted Count 46.01349609375
# ground trueth count 49.989445
# Model Predicted Count 72.184873046875
# ground trueth count 67.75463
# Model Predicted Count 51.6828662109375
# ground trueth count 57.262222
# Model Predicted Count 64.941181640625
# ground trueth count 118.33696
# Model Predicted Count 67.0260888671875
# ground trueth count 164.98573
# Model Predicted Count 104.25265625
# ground trueth count 166.65761
# Model Predicted Count 77.644208984375
# ground trueth count 52.80738
# Model Predicted Count 42.45654296875
# ground trueth count 293.6315
# Model Predicted Count 180.1314453125
# ground trueth count 12.53433
# Model Predicted Count 8.20456298828125
# ground trueth count 65.776794
# Model Predicted Count 20.64103759765625
# ground trueth count 122.72498
# Model Predicted Count 108.739384765625
# ground trueth count 140.96468
# Model Predicted Count 82.066875
# ground trueth count 100.397804
# Model Predicted Count 57.4010302734375
# ground trueth count 41.05891
# Model Predicted Count 55.9516259765625
# ground trueth count 9.443878
# Model Predicted Count 12.057142333984375
# ground trueth count 39.021294
# Model Predicted Count 21.8194970703125
# ground trueth count 72.7649
# Model Predicted Count 48.0255322265625
# ground trueth count 225.10805
# Model Predicted Count 60.166171875
# ground trueth count 17.317997
# Model Predicted Count 50.7444287109375
# ground trueth count 96.63585
# Model Predicted Count 57.5020458984375
# ground trueth count 233.38963
# Model Predicted Count 117.79654296875
# ground trueth count 58.059357
# Model Predicted Count 42.4369677734375
# ground trueth count 242.92873
# Model Predicted Count 145.37283203125
# ground trueth count 180.35274
# Model Predicted Count 119.26970703125
# ground trueth count 102.97569
# Model Predicted Count 64.8443115234375
# ground trueth count 183.50833
# Model Predicted Count 87.068876953125
# ground trueth count 35.030888
# Model Predicted Count 43.817451171875
# ground trueth count 52.895588
# Model Predicted Count 64.277744140625
# ground trueth count 157.8909
# Model Predicted Count 94.938076171875
# ground trueth count 97.610146
# Model Predicted Count 94.83880859375
# ground trueth count 274.18323
# Model Predicted Count 186.6129296875
# ground trueth count 299.42303
# Model Predicted Count 96.742109375
# ground trueth count 86.529305
# Model Predicted Count 73.28119140625
# ground trueth count 165.22356
# Model Predicted Count 103.1543359375
# ground trueth count 54.147266
# Model Predicted Count 38.63339111328125
# ground trueth count 210.30305
# Model Predicted Count 86.81828125
# ground trueth count 56.45203
# Model Predicted Count 47.51724609375
# ground trueth count 8.420844
# Model Predicted Count 35.8532958984375
# ground trueth count 99.366104
# Model Predicted Count 74.3296484375
# ground trueth count 88.0287
# Model Predicted Count 67.394404296875
# ground trueth count 83.443756
# Model Predicted Count 78.6827099609375
# ground trueth count 46.654003
# Model Predicted Count 44.828447265625
# ground trueth count 47.852955
# Model Predicted Count 51.4053271484375
# ground trueth count 13.667174
# Model Predicted Count 32.40928466796875
# ground trueth count 125.920525
# Model Predicted Count 46.94671875
# ground trueth count 174.11285
# Model Predicted Count 67.718232421875
# ground trueth count 52.823143
# Model Predicted Count 23.5516015625
# ground trueth count 185.76202
# Model Predicted Count 75.4681201171875
# ground trueth count 144.78076
# Model Predicted Count 85.335048828125
# ground trueth count 147.5452
# Model Predicted Count 85.584384765625
# ground trueth count 101.37309
# Model Predicted Count 91.034970703125
# ground trueth count 68.3749
# Model Predicted Count 46.467607421875
# ground trueth count 83.24381
# Model Predicted Count 67.189619140625
# ground trueth count 32.232616
# Model Predicted Count 66.14330078125
# ground trueth count 48.96371
# Model Predicted Count 35.80720947265625
# ground trueth count 86.41542
# Model Predicted Count 48.9434814453125
# ground trueth count 135.17993
# Model Predicted Count 81.093173828125
# ground trueth count 133.447
# Model Predicted Count 102.0894921875
# ground trueth count 154.62599
# Model Predicted Count 125.64048828125
# ground trueth count 280.87775
# Model Predicted Count 184.62259765625
# ground trueth count 46.667767
# Model Predicted Count 56.230205078125
# ground trueth count 444.17093
# Model Predicted Count 98.0666015625
# ground trueth count 66.25476
# Model Predicted Count 59.693271484375
# ground trueth count 105.018074
# Model Predicted Count 89.400791015625
# ground trueth count 67.89371
# Model Predicted Count 44.6592431640625
# ground trueth count 297.62106
# Model Predicted Count 182.89546875
# ground trueth count 142.49495
# Model Predicted Count 96.351728515625
# ground trueth count 69.76304
# Model Predicted Count 55.467294921875
# ground trueth count 150.86171
# Model Predicted Count 78.017724609375
# ground trueth count 257.6029
# Model Predicted Count 107.8575390625
# ground trueth count 90.67259
# Model Predicted Count 25.292861328125
# ground trueth count 136.60849
# Model Predicted Count 61.0567333984375
# ground trueth count 157.7507
# Model Predicted Count 42.858916015625
# ground trueth count 59.96057
# Model Predicted Count 37.157919921875
# ground trueth count 94.11827
# Model Predicted Count 92.65484375
# ground trueth count 237.8558
# Model Predicted Count 77.373974609375
# ground trueth count 25.695475
# Model Predicted Count 55.26306640625
# ground trueth count 75.96022
# Model Predicted Count 67.5340185546875
# ground trueth count 124.434555
# Model Predicted Count 55.9063525390625
# ground trueth count 88.76168
# Model Predicted Count 80.287880859375
# ground trueth count 320.0335
# Model Predicted Count 128.251435546875
# ground trueth count 191.23065
# Model Predicted Count 144.337490234375
# ground trueth count 208.18813
# Model Predicted Count 159.774853515625
# ground trueth count 178.09097
# Model Predicted Count 79.14173828125
# ground trueth count 91.90443
# Model Predicted Count 48.4566748046875
# ground trueth count 47.557743
# Model Predicted Count 60.6543310546875
# ground trueth count 164.42355
# Model Predicted Count 78.7712841796875
# ground trueth count 74.82866
# Model Predicted Count 42.482734375
# ground trueth count 139.30435
# Model Predicted Count 122.9989453125
# ground trueth count 84.819084
# Model Predicted Count 83.76724609375
# ground trueth count 172.3258
# Model Predicted Count 108.981875
# ground trueth count 101.580215
# Model Predicted Count 105.323037109375
# ground trueth count 98.65683
# Model Predicted Count 53.85384765625
# ground trueth count 83.25593
# Model Predicted Count 79.5051318359375
# ground trueth count 372.68796
# Model Predicted Count 225.08423828125
# ground trueth count 268.03595
# Model Predicted Count 167.85046875
# ground trueth count 101.858444
# Model Predicted Count 73.5339404296875
# ground trueth count 23.042204
# Model Predicted Count 31.33013916015625
# ground trueth count 56.8815
# Model Predicted Count 51.7892529296875
# ground trueth count 213.55737
# Model Predicted Count 93.0294140625
# ground trueth count 29.591345
# Model Predicted Count 50.616513671875
# ground trueth count 123.93102
# Model Predicted Count 110.08888671875
# ground trueth count 86.46574
# Model Predicted Count 71.2313037109375
# ground trueth count 45.704388
# Model Predicted Count 22.5697119140625
# ground trueth count 191.03653
# Model Predicted Count 119.588935546875
# ground trueth count 48.84656
# Model Predicted Count 20.106090087890625
# ground trueth count 128.75214
# Model Predicted Count 80.6330712890625
# ground trueth count 50.106308
# Model Predicted Count 75.6676611328125
# ground trueth count 82.801834
# Model Predicted Count 48.953759765625
# ground trueth count 180.8547
# Model Predicted Count 110.903076171875
# ground trueth count 34.782997
# Model Predicted Count 32.9204345703125
# ground trueth count 92.96467
# Model Predicted Count 53.6038525390625
# ground trueth count 32.34244
# Model Predicted Count 43.841181640625
# ground trueth count 136.61745
# Model Predicted Count 58.80728515625
# ground trueth count 56.96647
# Model Predicted Count 47.034189453125
# ground trueth count 54.886448
# Model Predicted Count 42.4334423828125
# ground trueth count 75.60373
# Model Predicted Count 76.436767578125
# ground trueth count 23.191471
# Model Predicted Count 28.98632080078125
# ground trueth count 50.08883
# Model Predicted Count 47.558876953125
# ground trueth count 300.52945
# Model Predicted Count 163.727138671875
# ground trueth count 137.79485
# Model Predicted Count 107.724228515625
# ground trueth count 203.34142
# Model Predicted Count 112.93501953125
# ground trueth count 189.71057
# Model Predicted Count 115.8259765625
# ground trueth count 159.09926
# Model Predicted Count 106.40470703125
# ground trueth count 57.417175
# Model Predicted Count 48.72458984375
# ground trueth count 84.2782
# Model Predicted Count 68.0123828125
# ground trueth count 35.75904
# Model Predicted Count 38.370009765625
# ground trueth count 64.02053
# Model Predicted Count 42.220302734375
# ground trueth count 52.293156
# Model Predicted Count 36.74552490234375
# ground trueth count 86.393295
# Model Predicted Count 66.7321630859375
# ground trueth count 144.62703
# Model Predicted Count 83.673623046875
# ground trueth count 195.03535
# Model Predicted Count 58.53048828125
# ground trueth count 56.276405
# Model Predicted Count 48.7819580078125
# ground trueth count 51.138676
# Model Predicted Count 33.80833984375
# ground trueth count 34.91503
# Model Predicted Count 36.95709716796875
# ground trueth count 21.762672
# Model Predicted Count 5.5389013671875
# ground trueth count 221.17638
# Model Predicted Count 85.025302734375
# ground trueth count 17.652971
# Model Predicted Count 41.278662109375
# ground trueth count 64.91945
# Model Predicted Count 69.3323486328125
# ground trueth count 85.95706
# Model Predicted Count 47.7003173828125
# ground trueth count 175.2342
# Model Predicted Count 88.716005859375
# ground trueth count 42.86865
# Model Predicted Count 42.7154052734375
# ground trueth count 87.1395
# Model Predicted Count 74.7564794921875
# ground trueth count 113.489494
# Model Predicted Count 71.853076171875
# ground trueth count 87.58605
# Model Predicted Count 72.738193359375
# ground trueth count 321.04398
# Model Predicted Count 189.86736328125
# ground trueth count 41.153393
# Model Predicted Count 47.8159326171875
# ground trueth count 24.249628
# Model Predicted Count 21.61601318359375
# ground trueth count 61.31544
# Model Predicted Count 19.86176513671875
# ground trueth count 200.47281
# Model Predicted Count 120.822880859375
# ground trueth count 149.80562
# Model Predicted Count 98.3639453125
# ground trueth count 94.94301
# Model Predicted Count 74.313447265625
# ground trueth count 57.417614
# Model Predicted Count 57.3701806640625
# ground trueth count 189.97939
# Model Predicted Count 50.31361328125
# ground trueth count 48.112255
# Model Predicted Count 54.2602099609375
# ground trueth count 30.133343
# Model Predicted Count 52.96205078125
# ground trueth count 170.87364
# Model Predicted Count 110.15666015625
# ground trueth count 76.739235
# Model Predicted Count 40.10027587890625
# ground trueth count 64.63494
# Model Predicted Count 76.1973583984375
# ground trueth count 108.209625
# Model Predicted Count 55.143837890625
# ground trueth count 42.55957
# Model Predicted Count 42.4507177734375
# ground trueth count 221.86891
# Model Predicted Count 130.5869140625
# ground trueth count 198.61226
# Model Predicted Count 100.983544921875
# ground trueth count 90.52791
# Model Predicted Count 69.1617529296875
# ground trueth count 173.19588
# Model Predicted Count 95.042099609375
# ground trueth count 61.78208
# Model Predicted Count 64.9259765625
# ground trueth count 46.697617
# Model Predicted Count 26.27231201171875
# ground trueth count 54.31454
# Model Predicted Count 26.26998291015625
# ground trueth count 26.833769
# Model Predicted Count 13.88554443359375
# ground trueth count 50.66639
# Model Predicted Count 64.05162109375
# ground trueth count 41.90292
# Model Predicted Count 21.9595458984375
# ground trueth count 49.57179
# Model Predicted Count 26.0094189453125
# ground trueth count 191.80528
# Model Predicted Count 125.64935546875
# ground trueth count 422.205
# Model Predicted Count 259.2993359375
# ground trueth count 163.95859
# Model Predicted Count 123.52919921875
# ground trueth count 37.454765
# Model Predicted Count 39.2379345703125
# ground trueth count 39.32774
# Model Predicted Count 50.8830908203125
# ground trueth count 154.02292
# Model Predicted Count 98.9772265625
# ground trueth count 89.29734
# Model Predicted Count 58.040224609375
# ground trueth count 43.948017
# Model Predicted Count 39.43923583984375
# ground trueth count 83.65422
# Model Predicted Count 61.5662548828125
# ground trueth count 102.00571
# Model Predicted Count 112.096337890625
# ground trueth count 31.076519
# Model Predicted Count 49.458291015625
# ground trueth count 329.60385
# Model Predicted Count 112.4399609375
# ground trueth count 36.698708
# Model Predicted Count 32.50700439453125
# ground trueth count 27.03773
# Model Predicted Count 62.22443359375
# ground trueth count 67.88705
# Model Predicted Count 43.959609375
# ground trueth count 84.819824
# Model Predicted Count 65.14662109375
# ground trueth count 151.62318
# Model Predicted Count 80.4227685546875
# ground trueth count 183.5982
# Model Predicted Count 56.6088330078125
# ground trueth count 32.935738
# Model Predicted Count 53.394775390625
# ground trueth count 260.8042
# Model Predicted Count 150.387744140625
# ground trueth count 79.88578
# Model Predicted Count 60.2333935546875
# ground trueth count 78.57657
# Model Predicted Count 65.3982275390625
# ground trueth count 44.503754
# Model Predicted Count 42.0785205078125
# ground trueth count 53.441147
# Model Predicted Count 34.36606201171875
# ground trueth count 23.336298
# Model Predicted Count 29.78432861328125
# ground trueth count 91.55054
# Model Predicted Count 37.99182861328125
# ground trueth count 77.50017
# Model Predicted Count 64.0710693359375
# ground trueth count 185.78818
# Model Predicted Count 70.0073876953125
# ground trueth count 76.18901
# Model Predicted Count 79.5051123046875
# ground trueth count 30.250963
# Model Predicted Count 11.82140869140625
# ground trueth count 44.634884
# Model Predicted Count 51.3230810546875
# ground trueth count 192.03545
# Model Predicted Count 136.02134765625
# ground trueth count 403.2402
# Model Predicted Count 233.28037109375
# ground trueth count 57.08738
# Model Predicted Count 57.6643408203125
# ground trueth count 226.79413
# Model Predicted Count 154.125693359375
# ground trueth count 47.164818
# Model Predicted Count 38.53555908203125
# ground trueth count 164.28893
# Model Predicted Count 93.073603515625
# ground trueth count 106.83117
# Model Predicted Count 52.1968408203125
# ground trueth count 53.92906
# Model Predicted Count 64.4328662109375
# ground trueth count 172.23111
# Model Predicted Count 74.799365234375
# ground trueth count 90.69054
# Model Predicted Count 79.8127685546875
# ground trueth count 43.339233
# Model Predicted Count 34.32554931640625
# ground trueth count 43.38076
# Model Predicted Count 37.47446044921875
# ground trueth count 188.30641
# Model Predicted Count 136.14029296875
# ground trueth count 50.343033
# Model Predicted Count 38.8536669921875
# ground trueth count 258.45523
# Model Predicted Count 107.316728515625
# ground trueth count 538.1336
# Model Predicted Count 288.054453125
# ground trueth count 88.60863
# Model Predicted Count 74.06626953125
# ground trueth count 88.60684
# Model Predicted Count 33.88194580078125
# ground trueth count 212.12685
# Model Predicted Count 110.36857421875
# ground trueth count 117.49258
# Model Predicted Count 49.2521044921875
# ground trueth count 277.31372
# Model Predicted Count 102.07423828125
# ground trueth count 58.63535
# Model Predicted Count 19.528455810546873
# ground trueth count 465.6679
# Model Predicted Count 139.29982421875
# ground trueth count 40.70603
# Model Predicted Count 59.9752685546875
# ground trueth count 127.29127
# Model Predicted Count 66.247373046875
# ground trueth count 52.385715
# Model Predicted Count 9.21828369140625
# ground trueth count 58.24729
# Model Predicted Count 24.481748046875
# ground trueth count 47.96912
# Model Predicted Count 57.4666650390625
# ground trueth count 54.161697
# Model Predicted Count 47.4632373046875
# ground trueth count 20.714314
# Model Predicted Count 75.64619140625
# ground trueth count 161.51198
# Model Predicted Count 64.239921875
# ground trueth count 51.572605
# Model Predicted Count 57.2672509765625
# ground trueth count 34.70074
# Model Predicted Count 38.50830322265625
# ground trueth count 88.66416
# Model Predicted Count 79.377041015625
# ground trueth count 193.8328
# Model Predicted Count 60.0854931640625
# ground trueth count 59.16315
# Model Predicted Count 58.8355908203125
# ground trueth count 211.18245
# Model Predicted Count 111.66416015625
# ground trueth count 44.724964
# Model Predicted Count 55.1933349609375
# ground trueth count 206.32407
# Model Predicted Count 123.80330078125
# ground trueth count 48.056164
# Model Predicted Count 13.95991455078125
# ground trueth count 239.9705
# Model Predicted Count 138.9630078125
# ground trueth count 103.79366
# Model Predicted Count 98.6083984375
# ground trueth count 111.790985
# Model Predicted Count 46.5711279296875
#  * TESTING MAE 49.310
